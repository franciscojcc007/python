# %%
import pandas as pd

# %%
dato = pd.read_csv('alquiler.csv', sep =';')

# %%
dato.head(10)

# %%
dato['Tipo']

# %%
dato.Tipo

# %%
tipo_local = dato.Tipo

# %%
type(tipo_local)

# %%
tipo_local.drop_duplicates()

# %%
tipo_local

# %%
tipo_local.drop_duplicates(inplace = True)

# %%
tipo_local

# %% [markdown]
# ***organizando la visualizacion***

# %%
tipo_local.index

# %%
tipo_local = pd.DataFrame(tipo_local)

# %%
tipo_local.shape[0]

# %%
for i in range(tipo_local.shape[0]):
  print(i)

# %%
tipo_local.index = range(tipo_local.shape[0])

# %%
tipo_local.index

# %%
tipo_local

# %%
tipo_local.columns.name = ' id'

# %%
tipo_local
