# %%
#mi arreglo de carros
carros=["Lamborghini","Volvo","Jaguar","Porsche","Rolls-Royce","Volkswagen","McLaren","Acura","Ford","Dodge","Mercedes-Benz","Ferrari","Chevrolet","Aston Martin","BMW"]
x=carros[10]
print("posición de carros que me gusta es",x)
# esta dos lineas es para mostrar cuantos elemento hay 
x=len(carros)
print("este arreglo tiene",x,"posiciones")
# Out:
# posicion de carros que me gusta es Mercedes-Benz
# este arreglo tiene 15 posiciones
