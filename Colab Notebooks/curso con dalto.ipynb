# %%
curso_min = 2.5
curso_max = 7
curso_prom = 4
dalto_prom = 1.5
crudo_prom = 5
curso_dalto = 3.5

diferencia_curso_min = 100- dalto_prom / curso_min * 100
diferencia_curso_max = 100- dalto_prom * 1000 // curso_max / 10
diferencia_curso_prom = 100- dalto_prom / curso_prom * 100

tiempo_v_prom= 100 - curso_prom * 1000 // crudo_prom / 10
tiempo_v_prom= 100 - curso_prom * 1000 // crudo_prom / 10

print('El cuerso de Dalto duro un')
print(f'-- {diferencia_curso_min}% menos que el mas rapido')
print(f'-- {diferencia_curso_max}% menos que el mas lento')
print(f'-- {diferencia_curso_prom}% menos que el promedio')
# Out:
# El cuerso de Dalto duro un
# -- 40.0% menos que el mas rapido
# -- 78.6% menos que el mas lento
# -- 62.5% menos que el promedio
