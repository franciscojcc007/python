# %%
cadena1="hola,feo,carro,agua"
cadena2="Soy Programador"

#convierste a mayusculas
mayusc= cadena1.upper()

#convierte a minusculas
minusc= cadena1.lower()

#primera letra de mayuscula
primer_letra_mayusc= cadena1.capitalize()

#buscamos una cadena en otra cadena, si no lo encuentra, devuelve -1
busqueda_find = cadena1.find("")

#buscamos una cadena en otra cadena, si no lo encuentra, devuelve una execion
busquda_index = cadena1.index("")

#si es numerico devuelve true, si no es numerico devuelve false
es_numerico = cadena1.isnumeric()

#si es alfanumerico devuelve true, si no es alfanumerico devuelve False
es_alfanumerico = cadena1.isalpha()

#separar cadenas con la cadena que el pasemos
cadena_separada= cadena1.split(",")

print(type(cadena_separada))
# Out:
# <class 'list'>
