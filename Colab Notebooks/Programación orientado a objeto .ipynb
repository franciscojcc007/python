# %%
class Persona:
  pass 
marisol = Persona()
dominingo = Persona()

#object.atributo =valor

marisol.edad = 42
marisol.sexo = "Femenino"
marisol.pais = "R.Dominicana"
dominingo.edad = 20
dominingo.sexo = "Masculino"
dominingo.pais = "R.Dominicana"
print(marisol.edad,marisol.sexo,marisol.pais)
print(dominingo.edad,dominingo.sexo,dominingo.pais)
# Out:
# 42 Femenino R.Dominicana
# 20 Masculino R.Dominicana

# %%
#class nombre de la clase : 
  #def nombre del metdo (self):
#self.nombre de la variable = algoritmo

class Matematica:
  def suma(self):
    self.n1 = 10
    self.n2 = 5
sumando = Matematica() 
sumando.suma()
print(sumando.n1 + sumando.n2)

# %%
#uso del __init__(seft)
class Casa:
  def __init__(self):
      self.color = "Verde cielo "
      self.ciudad = "La Romana "
      self.estado = "Nueva"

Apartamento = Casa()
print(Apartamento.color,Apartamento.ciudad,Apartamento.estado)
# Out:
# Verde cielo  La Romana  Nueva
