# %%
import pandas as pd

# %%
df_json = pd.read_json('data/alquiler.json')
df_json

# %%
df_txt = pd.read_table('data/alquiler.txt')
df_txt

# %%
df_xlsx = pd.read_excel('data/alquiler.xlsx')
df_xlsx

# %%
#df_html =pd.read_html('data/datos_html_1.html')
#df_html[0]

# %%
df_html = pd.read_html('https://es.wikipedia.org/wiki/Wikipedia:Portada')
len(df_html)

# %%
df_html[0]
