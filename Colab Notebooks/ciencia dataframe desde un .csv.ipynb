# %%
import pandas as pd
#pd.set_option('display.max_rows',10)
#pd.set_option('display.max_columns',10)
data = pd.read_csv('alquiler.csv', sep=';')

# %% [markdown]
# **Reporte del analisis del semestre**

# %%
data

# %%
data.describe()

# %%
type(data)

# %%
data.info()

# %%
data.head(20)

# %% [markdown]
# # informaciones generales

# %%
tipo_de_datos = pd.DataFrame(data.dtypes,columns = ['tipos de datos'])
tipo_de_datos.columns.name = 'variables'

# %%
tipo_de_datos

# %%
print('la base de datos presenta {} fila y {} coluna'.format(data.shape[0], data.shape[1]))
# Out:
# la base de datos presenta 32960 fila y 9 coluna
