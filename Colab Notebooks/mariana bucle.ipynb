# %%
nombre = 5

while nombre < 30:
  print("francisco")
  nombre +=2
# Out:
# francisco
# francisco
# francisco
# francisco
# francisco
# francisco
# francisco
# francisco
# francisco
# francisco
# francisco
# francisco
# francisco
