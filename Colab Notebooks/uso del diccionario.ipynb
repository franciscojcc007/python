# %%
lista=["hola","adios","loco", 12,False]
#print(lista)

tuple = ("hola","adios","loco", 12,False)
#print(tuple)

conjunto = {"hola","adios","loco", 12,False}
#print(conjunto)

diccionario = {
    'saludo':"hola",
    'despedida':"adios",
    'insulto':"loco",
    'numero': 12,
    'esta_emocionado':False
    }
print(diccionario['despedida'])
# Out:
# adios
