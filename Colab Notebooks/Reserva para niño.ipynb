# %%
edad= int(input("cuantos aÑos tiene el niÑo ")) 

if edad >= 13: (
   print ("Tiene o es mayor de 13 aÑos paga como adulto, pagara 150 dólares, su edad es ",edad)
)

elif edad >= 6 and edad <= 12: (
   print ("Es encuentra entre la edad de 6 a 12 por lo tanto Tiene un 50% de descuento, su edad es ",edad) 
)

else : (
   print ("es menor de 5 por lo tanto es gratis, su edad es",edad)
)
# Out:
# cuantos aÑos tiene el niÑo 4
# es menor de 5 por lo tanto es gratis, su edad es 4
