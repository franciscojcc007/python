# %%
print("^^^^^^^^^^^^^^^^^^^^^^^^^")
print("    programa ABM         ")
print("*************************\n")
selec= int(input("Seleccioné una opción "))
A= (1)
M= (2)
B= (3)

if selec == A: (
   print("Agregar estudiante.")
)
elif selec == M: (
    print("Modificar estudiante.")
)
elif selec == B: (
    print("Borrar estudiante.")
)
else : (
    print("Opción no valida.")
)
