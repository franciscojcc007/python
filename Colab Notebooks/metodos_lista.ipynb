# %%
#creando una lista con list()
lista = list(["hola", "mundo",54,60,"roma"])

#devuelve la cantidad de elementos de la lista
cantidad_elementos = (lista)

#agregando un elemento a al lista
lista.append("jajaja")

#agregando un elemento a al lista en un indice especifico
lista.insert(2, "toma mama")

#agregando varios elementos a la lista
lista.extend([True,2030])

#aliminando un elemento de la lista (por su indice)
lista.pop(2)

#removiendo un elemento de la lista por su valor
lista.remove("jajaja")


#eliminando todos los elementos de la lista
#lista.clear()

#ordenando la lista de forma ascendente(si usamos el parametro el reverse=True lo ordena en reversa)
#lista.sort()

#invirtiendo la lista de forma descendente(si usamos el parametro el reverse=False
lista.reverse()

print(lista)
# Out:
# [2030, True, 'roma', 60, 54, 'mundo', 'hola']
