# %%
print("*****************************\n")
print("<<<<<<< Calculadora >>>>>>>>>")
print("_____________________________\n")
n1 = float(input("Dime tu primer número: "))
n2 = float(input("Dime tu segundo número: "))

opcion = 0
while True:
    print("""
    Dime, ¿qué quieres hacer?\n
    1) Sumar los dos números
    2) Restar los dos números
    3) Multiplicar los dos números
    4) divide los dos numero
    5) Cambiar los números elegidos
    6) Apagar calculadora
    """)
    opcion = int(input("Elige una opción a realizar: "))     

    if opcion == 1:
        print(" ")
        print("RESULTADO: La suma de",n1,"+",n2,"es igual a",n1+n2)
    elif opcion == 2:
        print(" ")
        print("RESULTADO: La resta de",n1,"-",n2,"es igual a",n1-n2)
    elif opcion == 3:
        print(" ")
        print("RESULTADO: El producto de",n1,"*",n2,"es igual a",n1*n2)
    elif opcion == 4:
        print(" ")
        print("RESULTADO: El producto de",n1,"/",n2,"es igual a",n1/n2)
    elif opcion == 5:
        n1 = float(input("Dime tu primer número: "))
        n2 = float(input("Dime tu segundo número: "))
    elif opcion == 6:
        break
    else:
        print("Opción incorrecta")
# Out:
# *****************************
#
# <<<<<<< Calculadora >>>>>>>>>
# _____________________________
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 4
#       2 print("<<<<<<< Calculadora >>>>>>>>>")
#       3 print("_____________________________\n")
# ----> 4 n1 = float(input("Dime tu primer número: "))
#       5 n2 = float(input("Dime tu segundo número: "))
#       7 opcion = 0
#
# ValueError: could not convert string to float: ''

# %%
def suma(n1,n2):
  
     return n1+n2;

def resta(n1,n2):

     return n1-n2;  

def Multiplicar(n1,n2):

     return n1*n2;

def dividir(n1,n2):
     
     return n1/n2;

# %%
print("*****************************\n")
print("<<<<<<< Calculadora >>>>>>>>>")
print("_____________________________\n")
n1 = float(input("Dime el primer numeros: "))
n2 = float(input("Dime el primer numeros: "))
print("""
     1) Sumar los dos números
     2) Restar los dos números
     3) Multiplicar los dos números
     4) divider los dos numero
     """)
opcion =float(input("por favor, elija una opcion "))
if opcion == 1:
     print(suma(n1,n2))

elif opcion == 2:
     print(resta(n1,n2))

elif opcion == 3:    
     print(Multiplicar(n1,n2))

elif opcion == 4:
     print(dividir(n1,n2))

else:
     print("opcion erronia");
# Out:
# *****************************
#
# <<<<<<< Calculadora >>>>>>>>>
# _____________________________
